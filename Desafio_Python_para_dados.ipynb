# %% [markdown]
# <a href="https://colab.research.google.com/github/adhalya/desafio_python/blob/main/Desafio_Python_para_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Considerando a base de dados de saude_do_sono_estilo_vida.csv responda
# as questões abaixo.**
#
# Você é uma pesquisadora que está tentando entender melhor qual o impacto
# do estilo de vida de uma pessoa na sua qualidade de sono, por isso fez a
# coleta dos dados de 373 pessoas, onde foram recolhidas 12 características para cada uma delas. Por competência, a sua pesquisa foi bem controlada e você não tem dados faltosos na sua base.
#
# Chegou o momento de você fazer sua análise e responder algumas perguntas.

# %%
# !pip install pandas

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/adhalya/desafio_python/main/saude_do_sono_estilo_vida.csv')

df.head()
# Out:
#    ID Gênero  Idade                 Ocupação  Duração do sono  \
# 0   1  Homem     27         Eng. de Software              6.1
# 1   2  Homem     28                Médico(a)              6.2
# 2   3  Homem     28                Médico(a)              6.2
# 3   4  Homem     28  Representante de Vendas              5.9
# 4   5  Homem     28  Representante de Vendas              5.9
#
#    Qualidade do sono  Nível de atividade física  Nível de estresse  \
# 0                  6                         42                  6
# 1                  6                         60                  8
# 2                  6                         60                  8
# 3                  4                         30                  8
# 4                  4                         30                  8
#
#   Categoria BMI Pressão sanguíneaaaa  Frequência cardíaca  Passos diários  \
# 0     Sobrepeso               126/83                   77            4200
# ...

# %% [markdown]
# 1. Ao visualizar a base você percebeu que seria melhor alterar o nome de algumas colunas. Mude o ‘ID’ para ‘Identificador’, corrija o nome da coluna que indica a pressão sanguínea, mude a coluna ‘Ocupação’ para ‘Profissão’, a coluna ‘Categoria BMI’ está em parte em inglês, substitua para ‘Categoria IMC’.

# %%
n_colunas = {'ID': 'Identificador',
             'Pressão sanguíneaaaa': 'Pressão sanguínea',
             'Ocupação': 'Profissão',
             'Categoria BMI': 'Categoria IMC'}

df.rename(columns=n_colunas, inplace=True)

df.head()
# Out:
#    Identificador Gênero  Idade                Profissão  Duração do sono  \
# 0              1  Homem     27         Eng. de Software              6.1
# 1              2  Homem     28                Médico(a)              6.2
# 2              3  Homem     28                Médico(a)              6.2
# 3              4  Homem     28  Representante de Vendas              5.9
# 4              5  Homem     28  Representante de Vendas              5.9
#
#    Qualidade do sono  Nível de atividade física  Nível de estresse  \
# 0                  6                         42                  6
# 1                  6                         60                  8
# 2                  6                         60                  8
# 3                  4                         30                  8
# 4                  4                         30                  8
#
#   Categoria IMC Pressão sanguínea  Frequência cardíaca  Passos diários  \
# ...

# %% [markdown]
# 2. Qual é a média, a moda e a mediana de horas de sono para cada uma das profissões? [‘mean’, np.median, pd.Series.mod]

# %%
def estatistica(coluna):
  return coluna.mean().round(1), coluna.median(), coluna.mode()

df.groupby('Profissão')['Duração do sono'].agg(estatistica)
# Out:
# Profissão
# Advogado(a)                     (7.4, 7.3, [7.2])
# Cientista                  (6.0, 6.0, [5.8, 6.2])
# Contador(a)                     (7.1, 7.2, [7.2])
# Enfermeiro(a)                   (7.0, 6.5, [6.1])
# Eng. de Software                (6.8, 6.8, [7.5])
# Engenheiro(a)                   (8.0, 8.3, [8.4])
# Gerente                         (6.9, 6.9, [6.9])
# Médico(a)                       (7.0, 7.6, [6.0])
# Pessoa Vendendora               (6.4, 6.4, [6.5])
# Professor(a)                    (6.7, 6.6, [6.6])
# Representante de Vendas         (5.9, 5.9, [5.9])
# Name: Duração do sono, dtype: object

# %% [markdown]
# 3. Das pessoas que atuam com engenharia de software qual a porcentagem de obesos?

# %%
#Filtrando quantidade de pessoas engenheiras de software na coluna profissão
p_eng_software = df['Profissão'] == 'Eng. de Software'
total_p_eng_software = len(df[p_eng_software])

# Filtrando quantidade de pessoas obesas engenheiras de software
filtro_p_obesas_eng_software = (df['Categoria IMC'] == 'Obesidade') & (df['Profissão'] == 'Eng. de Software')
p_obesas_eng_software = len(df[filtro_p_obesas_eng_software])

# Calculando a porcentagem de pessoas obesas engenheiras de software
perc_p_obesas_eng_software = (p_obesas_eng_software / total_p_eng_software) * 100

# Arredondando o valor para duas casas decimais
perc_p_obesas_eng_software = round(perc_p_obesas_eng_software, 2)

# Imprimindo o resultado
print('O percentual de obesos que atuam com engenharia de software é de', perc_p_obesas_eng_software, '%')
# Out:
# O percentual de obesos que atuam com engenharia de software é de 25.0 %

# %% [markdown]
# 4. De acordo com os dados, advogar ou ser representante de vendas faz você dormir menos? (Use o método ‘isin’, considere a média)

# %%
# Filtragem das profissões Advogado(a) e Representante de Vendas
filtro_profissao = df[df['Profissão'].isin(['Advogado(a)', 'Representante de Vendas'])]

# Realizando a média das duas profissões e apresentando em 2 casas decimais em ordem descrecente
media_sono = filtro_profissao.groupby('Profissão')['Duração do sono'].mean().sort_values(ascending=True).round(2)

# Imprimindo o resultado
media_sono
# Out:
# Profissão
# Representante de Vendas    5.90
# Advogado(a)                7.41
# Name: Duração do sono, dtype: float64

# %% [markdown]
# 5. Entre quem fez enfermagem e quem fez medicina, quem tem menos horas de sono? (Use o método ‘isin’, considere a média)

# %%
# Filtragem das profissões Enfermeiro(a) e Médico(a)
filtro_profissao2 = df[df['Profissão'].isin(['Enfermeiro(a)', 'Médico(a)'])]

# Realizando a média das duas profissões e apresentando em 2 casas decimais em ordem descrecente
media_sono2 = filtro_profissao2.groupby('Profissão')['Duração do sono'].mean().sort_values(ascending=True).round(2)

# Imprimindo o resultado
media_sono2
# Out:
# Profissão
# Médico(a)        6.97
# Enfermeiro(a)    7.05
# Name: Duração do sono, dtype: float64

# %% [markdown]
# 6. Faça um subconjunto com as colunas Identificador, Gênero, Idade, Pressão sanguínea e Frequência cardíaca.

# %%
# Separação das colunas solicitadas na variável subconjunto_df
subconjunto_df = df[['Identificador', 'Gênero', 'Idade', 'Pressão sanguínea', 'Frequência cardíaca']]

# Imprimindo o resultado
subconjunto_df.head()
# Out:
#    Identificador Gênero  Idade  Pressão sanguínea  Frequência cardíaca
# 0              1  Homem     27              12683                   77
# 1              2  Homem     28              12580                   75
# 2              3  Homem     28              12580                   75
# 3              4  Homem     28              14090                   85
# 4              5  Homem     28              14090                   85

# %% [markdown]
# 7. Descubra qual a profissão menos frequente no conjunto. (Use value_counts)

# %%
# Realizando a contagem da frequencia das profissões e apresentando em ordem decrescente
freq_profissao = df['Profissão'].value_counts().sort_values(ascending=True)

# Imprimindo o resultado
freq_profissao
# Out:
# Gerente                     1
# Representante de Vendas     2
# Eng. de Software            4
# Cientista                   4
# Pessoa Vendendora          32
# Contador(a)                37
# Professor(a)               40
# Advogado(a)                47
# Engenheiro(a)              63
# Médico(a)                  71
# Enfermeiro(a)              72
# Name: Profissão, dtype: int64

# %% [markdown]
# 8. Quem tem maior pressão sanguínea média, homens ou mulheres? (Considere a média)

# %%
# Removendo o "/" e dividindo os números da pressão sanguínea
df['Pressão sanguínea'] = df['Pressão sanguínea'].str.replace('/', '')

# Transformando os números em inteiros para realizar o cálculo de média
df['Pressão sanguínea'] = df['Pressão sanguínea'].astype(int)

# Filtrando os dados para obter apenas homens e mulheres
filtro_homens = df[df['Gênero'] == 'Homem']
filtro_mulheres = df[df['Gênero'] == 'Mulher']

# Calculando a média da pressão sanguínea para homens e mulheres
media_pressao_homens = filtro_homens['Pressão sanguínea'].mean()
media_pressao_mulheres = filtro_mulheres['Pressão sanguínea'].mean()

# Comparando e imprimindo a resposta para a pergunta
if media_pressao_homens > media_pressao_mulheres:
    print("Homens têm uma pressão sanguínea média maior.")
elif media_pressao_homens < media_pressao_mulheres:
    print("Mulheres têm uma pressão sanguínea média maior.")
else:
    print("Homens e mulheres têm a mesma pressão sanguínea média.")
# Out:
# Mulheres têm uma pressão sanguínea média maior.

# %% [markdown]
# 9. É predominante entre os participantes dormir 8 horas por dia (considere usar Moda como medida)?

# %%
moda_sono = df['Duração do sono'].mode()[0]

print('A predominância de horas de sono entre os participantes é de', moda_sono,'horas por dia!')
# Out:
# A predominância de horas de sono entre os participantes é de 7.2 horas por dia!

# %% [markdown]
# 10. Pessoas com frequências cardíacas acima de 70 dão mais passos que pessoas com frequência cardíaca menor ou igual a 70? (Use a média)

# %%
# Filtrar frequências cardíacas
acima_70 = df[df['Frequência cardíaca'] > 70]
menor_igual_70 = df[df['Frequência cardíaca'] <= 70]

# Filtrando os passos de acordo com a referência da frequencia cardíaca e tirando a média
media_passos_acima_70 = acima_70['Passos diários'].mean()
media_passos_menor_igual_70 = menor_igual_70['Passos diários'].mean()

# Comparando e imprimindo a resposta para a pergunta
if media_passos_acima_70 > media_passos_menor_igual_70:
    print("Pessoas com frequências cardíacas acima de 70 dão mais passos.")
elif media_passos_acima_70 < media_passos_menor_igual_70:
    print("Pessoas com frequências cardíacas igual ou abaixo de 70 dão mais passos.")
else:
    print("Não há diferença significativa no número de passos entre os dois grupos.")
# Out:
# Pessoas com frequências cardíacas igual ou abaixo de 70 dão mais passos.
